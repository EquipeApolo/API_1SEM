# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_FNT = pd.read_excel('STG_FNT_ITT.xlsx', delimiter = ';')
df_MVT = pd.read_excel('STG_MVT_CRD.xlsx',delimeter = ';')

# %%
df_FNT
# Out:
#       ID_STG_FNT_ITT     NUM_CNPJ  NUM_CMP_CNPJ NOM_COM NOM_RAZ_SCL  \
# 0                137   2427884087          2805     NMN         NMN
# 1                183  12182674487          2635     NMN         NMN
# 2                197  16167328168          1802     NMN         NMN
# 3                267    279925978          2329     NMN         NMN
# 4                322  20579036860          2397     NMN         NMN
# ...              ...          ...           ...     ...         ...
# 1003              87  11901046588          1972     NMN         NMN
# 1004             105  17765603364         13056     NMN         NMN
# 1005             118  17765603364        165138     NMN         NMN
# 1006             124  17765603364        238697     NMN         NMN
# 1007             125  17765603364        250206     NMN         NMN
#
#                   DAT_INC_DBO
# 0     2019-12-19 13:43:41.914
# 1     2019-12-19 13:43:41.914
# 2     2019-12-19 13:43:41.914
# ...

# %%
any(df_FNT.groupby(by='NUM_CNPJ').size()>1)
# Out:
# True

# %%
df_MVT
# Out:
#     ID_STG_MVT_CRD  VLR_SDO_UTZ_CRD_RTO   VLR_TOT_FAT   VLR_MIM_FAT  \
# 0                1                  NaN           NaN           NaN
# 1                2                  NaN           NaN           NaN
# 2                3                  NaN           NaN           NaN
# 3                4                  NaN           NaN           NaN
# 4                5                  NaN           NaN           NaN
# 5                6                  NaN           NaN           NaN
# 6                7                  NaN           NaN           NaN
# 7                8                  NaN           NaN           NaN
# 8                9                  NaN           NaN           NaN
# 9               10         2.181758e+10           NaN           NaN
# 10              11                  NaN           NaN           NaN
# 11              12                  NaN           NaN           NaN
# 12              13                  NaN           NaN           NaN
# ...

# %%
df_MVT.isnull().sum()
# Out:
# ID_STG_MVT_CRD          0
# VLR_SDO_UTZ_CRD_RTO    14
# VLR_TOT_FAT            14
# VLR_MIM_FAT            14
# VLR_PCL_FAT             2
# QTD_CLI_CAD_POS         0
# QTD_MVT                 0
# DES_TIP_PSS             0
# ID_FNT_ITT              0
# COD_MDL                 0
# DAT_RSS_FNT_ITT         0
# DAT_INC_DBO             0
# dtype: int64

# %%
df_FNT.isnull().sum()
# Out:
# ID_STG_FNT_ITT    0
# NUM_CNPJ          0
# NUM_CMP_CNPJ      0
# NOM_COM           0
# NOM_RAZ_SCL       0
# DAT_INC_DBO       0
# dtype: int64
